# %%
from elevator import create_elevator_animation

# %%
create_elevator_animation()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 create_elevator_animation()
#
# File ~/stuff/reaserch/spectabular/jupylet/elevator.py:122, in create_elevator_animation(start_floor, end_floor, speed)
#     119 cabin_w = SHAFT_W - 2 * CABIN_PAD
#     121 # cabin body
# --> 122 cabin = draw.Rectangle(cabin_x, start_cabin_y, cabin_w, CABIN_H,
#     123                        fill="#b0a898", stroke="#666", stroke_width=2, rx=3)
#     124 cabin.add_key_frame(t0, y=start_cabin_y)
#     125 cabin.add_key_frame(t2, y=start_cabin_y)
#
# NameError: name 'start_cabin_y' is not defined
